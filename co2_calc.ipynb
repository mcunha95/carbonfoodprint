# %%
import pandas as pd

# %%
food_data = pd.read_csv('./df/CleanFoodData.csv', sep=',')
food_data.rename(columns={'Mean': 'Mean_Food.g'}, inplace=True)
food_data['Mean_CO2.g'] = [0] * len(food_data) # Initialize column for CO2
food_data.head(3)
# Out:
#    Country Pop_Class    Food  ID  Nr_Consumer  Mean_Food.g  Mean_CO2.g
# 0  Austria    Adults  banana   1          105    37.134740           0
# 1  Austria    Adults  almond   2            8     0.344156           0
# 2  Austria    Adults   apple   3          213    90.806006           0

# %%
co2_data = pd.read_csv('./df/CO2Footprint.csv', sep=',', index_col = 0)
co2_data['Grams.CO2e.per.Grams'] = co2_data['Grams.CO2e.per.Serving']/co2_data['Serving.Size'] # Created column for CO2/grams of food
co2_data.head(3)
# Out:
#       Food         Category  Serving.Size  Calories.per.Serving  \
# ID
# 1   banana            Fruit         140.0                   112
# 2   almond  Nut/Seed/Legume          30.0                   172
# 3    apple            Fruit         140.0                    80
#
#     Grams.CO2e.per.Serving  Grams.CO2e.per.kcal  Grams.CO2e.per.Grams
# ID
# 1                    738.4                  3.7              5.274286
# 2                    166.1                  1.0              5.536667
# 3                    106.7                  1.3              0.762143

# %%
for iFood, foodRow in food_data.iterrows():
    for co2Id, co2Row in co2_data.iterrows():
        if co2Id == foodRow['ID']:
            food_data.loc[iFood,'Mean_CO2.g'] = foodRow['Mean_Food.g']*co2Row['Grams.CO2e.per.Grams']
            break
food_data
# Out:
#       Country    Pop_Class          Food  ID  Nr_Consumer  Mean_Food.g  \
# 0     Austria       Adults        banana   1          105    37.134740
# 1     Austria       Adults        almond   2            8     0.344156
# 2     Austria       Adults         apple   3          213    90.806006
# 3     Austria       Adults       apricot   4            7     1.209416
# 4     Austria       Adults    artichokes   5            2     0.659091
# 5     Austria       Adults     asparagus   6            4     0.691558
# 6     Austria       Adults       avocado   7            3     0.618912
# 7     Austria       Adults        barley   8            1     0.181818
# 8     Austria       Adults          beef   9           32     7.826299
# 9     Austria       Adults        pepper  10           66    10.405195
# 10    Austria       Adults   blueberries  11            4     0.775974
# 11    Austria       Adults      broccoli  12           10     1.890422
# 12    Austria       Adults       chicken  13           72    18.953003
# 13    Austria       Adults        butter  15          156     7.926542
# 14    Austria       Adults       cabbage  16           36     6.662338
# 15    Austria       Adults        carrot  18           45     7.511364
# 16    Austria       Adults   cauliflower  19            6     1.496753
# 17    Austria       Adults        celery  20            2     0.456169
# 18    Austria       Adults        cheese  21          353    35.621429
# 19    Austria       Adults         cocoa  22           56     2.758766
# 20    Austria       Adults          corn  25           22     2.058442
# 21    Austria       Adults   cranberries  27            3     0.209416
# 22    Austria       Adults      cucumber  28           40     7.095779
# 23    Austria       Adults         beans  29           33     6.568182
# 24    Austria       Adults      eggplant  30            5     0.805195
# 25    Austria       Adults           egg  31           73     9.774351
# 26    Austria       Adults          figs  32            2     0.084578
# 27    Austria       Adults          fish  33           34     6.825649
# 28    Austria       Adults        garlic  35            8     0.060065
# 29    Austria       Adults    grapefruit  36            3     1.555195
# ...       ...          ...           ...  ..          ...          ...
# 5222   Sweden  Adolescents          lamb  42            6     0.177800
# 5223   Sweden  Adolescents       lettuce  44           77     0.478798
# 5224   Sweden  Adolescents          milk  47         2665   443.701791
# 5225   Sweden  Adolescents     olive oil  50            9     0.057466
# 5226   Sweden  Adolescents        olives  51           14     0.139489
# 5227   Sweden  Adolescents         onion  52           81     0.462590
# 5228   Sweden  Adolescents        orange  53          230    16.765588
# 5229   Sweden  Adolescents         peach  56            8     0.347495
# 5230   Sweden  Adolescents       peanuts  57            7     0.032662
# 5231   Sweden  Adolescents          pear  58           84     5.119679
# 5232   Sweden  Adolescents     pineapple  62           23     0.692534
# 5233   Sweden  Adolescents     pistachio  63            2     0.021857
# 5234   Sweden  Adolescents          plum  64            2     0.059676
# 5235   Sweden  Adolescents          pork  65         1017    21.993772
# 5236   Sweden  Adolescents        potato  66         1709   109.967653
# 5237   Sweden  Adolescents   raspberries  68           32     0.191880
# 5238   Sweden  Adolescents         sugar  69         1010    14.394127
# 5239   Sweden  Adolescents        coffee  70           22     1.073183
# 5240   Sweden  Adolescents          peas  71           69     0.622544
# 5241   Sweden  Adolescents       spinach  75           32     0.669614
# 5242   Sweden  Adolescents  strawberries  76           22     0.413310
# 5243   Sweden  Adolescents    sweet corn  79          142     2.071546
# 5244   Sweden  Adolescents         grape  81           55     1.407171
# 5245   Sweden  Adolescents        tomato  83          815    11.170326
# 5246   Sweden  Adolescents        turkey  84           10     0.241650
# 5247   Sweden  Adolescents       walnuts  85            1     0.004912
# 5248   Sweden  Adolescents    watermelon  86           10     0.658399
# 5249   Sweden  Adolescents         wheat  87         4914   152.216428
# 5250   Sweden  Adolescents   wheat flour  88          755    17.247741
# 5251   Sweden  Adolescents          rice  89          704    33.752362
#
#       Mean_CO2.g
# 0     195.859230
# 1       1.905476
# 2      69.207149
# 3       0.668634
# 4       1.613610
# 5       2.403369
# 6       1.400805
# 7       0.126465
# 8      68.368309
# 9       9.768642
# 10      2.152219
# 11      1.723620
# 12     47.449010
# 13     44.067140
# 14      2.171138
# 15      3.084078
# 16      1.461536
# 17      0.215741
# 18    318.302908
# 19      4.027799
# 20      2.679650
# 21      0.459572
# 22      3.756589
# 23     16.176494
# 24      0.599633
# 25     29.054257
# 26      0.035221
# 27     25.676852
# 28      0.088496
# 29      0.295487
# ...          ...
# 5222    2.195045
# 5223    0.259114
# 5224  343.314261
# 5225    0.397035
# 5226    0.148788
# 5227    0.182315
# 5228    4.766217
# 5229    0.284698
# 5230    0.079369
# 5231    2.351395
# 5232    0.326480
# 5233    0.176455
# 5234    0.030989
# 5235  174.850488
# 5236   19.594236
# 5237    0.312489
# 5238   10.435742
# 5239    8.687861
# 5240    0.804913
# 5241    0.645980
# 5242    0.904264
# 5243    1.140569
# 5244    1.047337
# 5245   11.538289
# 5246    0.670795
# 5247    0.025540
# 5248    0.156370
# 5249   73.063886
# 5250   12.073418
# 5251   69.679876
#
# [5252 rows x 7 columns]

# %%
countries = list(food_data['Country'].unique())
#ageGroup =list(data['Pop_Class'].unique())
countries_df = pd.DataFrame(data=countries, columns="countries")
countries_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a991ff8fb454> in <module>()
#       1 countries = list(food_data['Country'].unique())
#       2 #ageGroup =list(data['Pop_Class'].unique())
# ----> 3 countries_df = pd.DataFrame(data=countries, columns="countries")
#       4 countries_df
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     401                 else:
#     402                     mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 403                                              copy=copy)
#     404             else:
#     405                 mgr = self._init_dict({}, index, columns, dtype=dtype)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _init_ndarray(self, values, index, columns, dtype, copy)
#     525                     raise_with_traceback(e)
#     526
# --> 527         index, columns = _get_axes(*values.shape)
#     528         values = values.T
#     529
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _get_axes(N, K, index, columns)
#     487                 columns = com._default_index(K)
#     488             else:
# --> 489                 columns = _ensure_index(columns)
#     490             return index, columns
#     491
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
#    4955             index_like = copy(index_like)
#    4956
# -> 4957     return Index(index_like)
#    4958
#    4959
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     423                          **kwargs)
#     424         elif data is None or is_scalar(data):
# --> 425             cls._scalar_data_error(data)
#     426         else:
#     427             if tupleize_cols and is_list_like(data) and data:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#     881         raise TypeError('{0}(...) must be called with a collection of some '
#     882                         'kind, {1} was passed'.format(cls.__name__,
# --> 883                                                       repr(data)))
#     884
#     885     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'countries' was passed

# %%
for i, ID in 
IDs = list(data['ID'])
IDs

# %%
for country in countries:
    total = 0
    for age in ageGroup:
        (subTotal = subTotal + data[] for

# %%
len(co2_data)
