# 5253   Sweden  Adolescents   wheat flour   17.247741  0
# 5254   Sweden  Adolescents          rice   33.752362  0
#
# [5255 rows x 5 columns]

# %%
data.loc[1:2,"Mean"]
# Out:
# 1     0.344156
# 2    90.806006
# Name: Mean, dtype: float64

# %%
countries = list(data['Country'].unique())
ageGroup = list(data['Pop_Class'].unique())
indexes=[];
total_group = 0
for country in countries:
    for age in ageGroup:
        for i, row in data.iterrows():
            if row['Country'] == country and row['Pop_Class'] == age:
                indexes.append(i)
                total_group = total_group + row['Mean']
    data.loc[indexes, 'Z'] = total_group
    indexes = []
    total_group = 0
data
# Out:
#       Country    Pop_Class          Food        Mean            Z  Mean_norm
# 0     Austria       Adults        banana   37.134740  5180.902218        inf
# 1     Austria       Adults        almond    0.344156  5180.902218        inf
# 2     Austria       Adults         apple   90.806006  5180.902218        inf
# 3     Austria       Adults       apricot    1.209416  5180.902218        inf
# 4     Austria       Adults    artichokes    0.659091  5180.902218        inf
# 5     Austria       Adults     asparagus    0.691558  5180.902218        inf
# 6     Austria       Adults       avocado    0.618912  5180.902218        inf
# 7     Austria       Adults        barley    0.181818  5180.902218        inf
# 8     Austria       Adults          beef    7.826299  5180.902218        inf
# 9     Austria       Adults        pepper   10.405195  5180.902218        inf
# 10    Austria       Adults   blueberries    0.775974  5180.902218        inf
# 11    Austria       Adults      broccoli    1.890422  5180.902218        inf
# 12    Austria       Adults       chicken   36.509821  5180.902218        inf
# 13    Austria       Adults        butter    7.926542  5180.902218        inf
# 14    Austria       Adults       cabbage    6.662338  5180.902218        inf
# 15    Austria       Adults        carrot    7.511364  5180.902218        inf
# 16    Austria       Adults   cauliflower    1.496753  5180.902218        inf
# 17    Austria       Adults        celery    0.456169  5180.902218        inf
# 18    Austria       Adults        cheese   35.621429  5180.902218        inf
# 19    Austria       Adults         cocoa    2.758766  5180.902218        inf
# 20    Austria       Adults          corn    2.058442  5180.902218        inf
# 21    Austria       Adults   cranberries    0.209416  5180.902218        inf
# 22    Austria       Adults      cucumber    7.095779  5180.902218        inf
# 23    Austria       Adults         beans    6.568182  5180.902218        inf
# 24    Austria       Adults      eggplant    0.805195  5180.902218        inf
# 25    Austria       Adults           egg   10.824675  5180.902218        inf
# 26    Austria       Adults          figs    0.084578  5180.902218        inf
# 27    Austria       Adults          fish   15.672727  5180.902218        inf
# 28    Austria       Adults        garlic    0.060065  5180.902218        inf
# 29    Austria       Adults    grapefruit    1.555195  5180.902218        inf
# ...       ...          ...           ...         ...          ...        ...
# 5225   Sweden  Adolescents          lamb    0.177800  7751.694494        inf
# 5226   Sweden  Adolescents       lettuce    0.478798  7751.694494        inf
# 5227   Sweden  Adolescents          milk  443.701791  7751.694494        inf
# 5228   Sweden  Adolescents     olive oil    0.057466  7751.694494        inf
# 5229   Sweden  Adolescents        olives    0.139489  7751.694494        inf
# 5230   Sweden  Adolescents         onion    0.462590  7751.694494        inf
# 5231   Sweden  Adolescents        orange   16.765588  7751.694494        inf
# 5232   Sweden  Adolescents         peach    0.347495  7751.694494        inf
# 5233   Sweden  Adolescents       peanuts    0.032662  7751.694494        inf
# 5238  6.289162e-03
# 5239  1.418627e-02
# 5240  2.475323e-05
# 5241  1.856901e-03
# 5242  1.384449e-04
# 5243  8.031072e-05
# 5244  8.638287e-05
# 5245  5.331872e-05
# 5246  2.672378e-04
# 5247  1.815308e-04
# 5248  1.441017e-03
# 5249  3.117387e-05
# 5250  6.336152e-07
# 5251  8.493612e-05
# 5252  1.963654e-02
# 5253  2.225028e-03
# 5254  4.354191e-03
#
# [5255 rows x 6 columns]

# %%
data.to_csv("./normalized_food_per_country_ageGroup.csv", header=True, sep=',', index=False)

# %%
countries = list(data['Country'].unique())
ageGroup =list(data['Pop_Class'].unique())
cols = ["Country", "ageGroup"] + list(set(data['Food']))
data_format = pd.DataFrame([[0]*(len(set(data['Food']))+2)]* len(data['Pop_Class'].unique()) * len(data['Country'].unique()), columns=cols)
i = 0
indexStart = 0
for country in countries:
    for age in ageGroup:
        data_format.loc[i,'Country'] = country
        data_format.loc[i,'ageGroup'] = age
        i+=1
        indexStart=i
    np.asarray(data.loc[indexStart:i, 'Mean_norm'])
    data_format.iloc[i,2:] = np.asarray(data.loc[indexStart:i, 'Mean_norm'])
    
        
data_format
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-8395c8e2d90b> in <module>()
#      12         indexStart=i
#      13     np.asarray(data.loc[indexStart:i, 'Mean_norm'])
# ---> 14     data_format.iloc[i,2:] = np.asarray(data.loc[indexStart:i, 'Mean_norm'])
#      15
#      16
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     187             key = com._apply_if_callable(key, self.obj)
#     188         indexer = self._get_setitem_indexer(key)
# --> 189         self._setitem_with_indexer(indexer, value)
#     190
#     191     def _validate_key(self, key, axis):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     604
#     605                     if len(labels) != len(value):
# --> 606                         raise ValueError('Must have equal len keys and value '
#     607                                          'when setting with an iterable')
#     608
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
np.asarray(data.loc[0:61, 'Mean_norm'])
# Out:
# array([7.16762037e-03, 6.64277822e-05, 1.75270643e-02, 2.33437253e-04,
#        1.27215470e-04, 1.33482242e-04, 1.19460339e-04, 3.50939227e-05,
#        1.51060537e-03, 2.00837506e-03, 1.49775849e-04, 3.64882794e-04,
#        7.04700067e-03, 1.52995403e-03, 1.28594160e-03, 1.44981768e-03,
#        2.88898185e-04, 8.80481453e-05, 6.87552613e-03, 5.32487609e-04,
#        3.97313339e-04, 4.04206788e-05, 1.36960300e-03, 1.26776796e-03,
#        1.55415943e-04, 2.08934175e-03, 1.63249408e-05, 3.02509613e-03,
#        1.15935280e-05, 3.00178374e-04, 4.70007893e-05, 2.78088003e-04,
#        9.40015786e-04, 1.49149171e-04, 1.92389898e-04, 2.19032452e-02,
#        7.76923047e-05, 8.27213892e-05, 3.34332281e-04, 8.27699566e-03,
#        4.70007893e-05, 1.32009550e-03, 1.46548461e-03, 4.69067877e-04,
#        1.98970008e-05, 1.30662194e-03, 8.06276607e-03, 9.63187175e-03,
#        8.96148383e-05, 3.34488950e-04, 4.42020490e-02, 1.95209945e-04,
#        3.09578532e-04, 2.13070245e-04, 2.46284136e-04, 2.26919811e-03,
#        3.77563607e-03, 1.76409629e-03, 9.63516180e-05, 1.66696133e-04,
#        4.77494492e-02, 4.88607672e-03])
